# %%
from os.path import dirname, join
import numpy as np
import matplotlib.pylab as plt

import blusky.datasets as datasets

# %%
test_data = join(dirname(datasets.__file__), join("test_tiles", "test_results.npz"))
test_data = np.load(test_data)

# %% [markdown]
# # Test data from Kymatio (2-D)
# The data was generated from Kymatio 2-D library for each of the test images in the datasets directory.
# The size of the images are 99x99, values of J = 6, everything else used the default settings.

# %%
scattering_coefs = test_data['salt0']
plt.figure()
plt.plot(scattering_coefs[1:])
plt.show()

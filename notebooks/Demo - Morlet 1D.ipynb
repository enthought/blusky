# %%
# %matplotlib inline
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
from scipy.signal import morlet

import pylab as plt

# %%
test_wl = morlet(100)

# %%
fig, ax = plt.subplots(1,2)
ax[0].plot(test_wl.real)
ax[1].plot(test_wl.imag)

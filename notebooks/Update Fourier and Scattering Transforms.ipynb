# %% [markdown]
# # Reproduce Figure 3 of Group Invariant Scattering (Mallat, 2012)

# %%
# %matplotlib inline

import pylab as plt

import numpy as np

from scipy.fftpack import fft
from scipy.signal import unit_impulse

from blusky.transforms.apply_father_wavelet_1d import ApplyFatherWavlet1D
from blusky.transforms.cascade_tree import CascadeTree
from blusky.transforms.cascade_1d import Cascade1D
from blusky.transforms.default_decimation import (NoDecimation, 
                                                  DefaultDecimation)
from blusky.transforms.i_decimation_method import IDecimationMethod
from blusky.wavelets.i_wavelet_1d import IWavelet1D
from blusky.utils.pad_1d import pad_to_log2, Pad1D
from blusky.wavelets.wavelet_factories_1d import (vanilla_gabor_1d, 
                                                  vanilla_morlet_1d,
                                                  calibrate_wavelets_1d)
from keras.layers import Input
from keras import Model
# Out:
# Using TensorFlow backend.

# %%
# why do you have to be so large!?
N = 4*1024 # signal size, power of two

# example signals
# Indicator function of an interval
R = 20 #half width of window
start = np.int(N/2-R)
end = np.int(N/2 + R)

f1 = np.zeros(N)
f1[start:end] = 1
f1 = f1 /np.sum(np.abs(f1));
A1 = np.abs(fft(f1))

# First Gabor function
x = np.arange(N)+1
f2 = np.exp((-(x-N/2)**2)/2048)*np.cos(np.pi*x*0.9/3)
f2 = f2 / np.sum(np.abs(f2))
A2 = np.abs(fft(f2))

# Dilated Gabor Function
f3 = np.exp((-(2.)**2*(x-N/2)**2)/2048)*np.cos(np.pi*x*2.*0.9/3)
f3 = f3 / np.sum(np.abs(f3))
A3 = np.abs(fft(f3))

# Sum of a Gabor function and a dilated Gabor function
f4 = np.exp((-(x-N/2)**2)/8192)*np.cos(np.pi*x*0.95/3) + np.exp((-(x-N/2)**2)/8192)*np.cos(np.pi*x*1/3*1.05)
f4 = f4 /np.sum(np.abs(f4));
A4 = np.abs(fft(f4))

# %%
order = 2
sample_rate = 0.001

# for the father wavelet
# make this larger to remove the decimatoion
oversampling = 1
# if you want to stop decimation this needs to be "same"
father_padding = "valid"
# There's no need to change this:
conv_padding = "valid"

J = 8

wavelets = [vanilla_morlet_1d(sample_rate, J, j=i) 
                    for i in range(0,J)]
calibrate_wavelets_1d(wavelets)

father_wavelet = vanilla_gabor_1d(sample_rate, J)

deci = DefaultDecimation(oversampling=oversampling)
#deci = NoDecimation()

inp = Input(shape=(N,1))

# pad
pad_1d = Pad1D(wavelets, decimation=deci, conv_padding=conv_padding)
padded = pad_1d.pad(inp)

#
cascade_tree = CascadeTree(padded, order=order)

cascade = Cascade1D(decimation=deci, _padding=conv_padding)
convs = cascade.transform(cascade_tree, wavelets=wavelets)

# Create layers to remove padding
cascade_tree = CascadeTree(padded, order=order)
cascade_tree.generate(wavelets, pad_1d.unpad)
unpad = cascade_tree.get_convolutions()

# Remove the padding
unpadded_convs = [i[1](i[0]) for i in zip(convs, unpad)]

# the paper sets: fparam.J = Jmax-1
# 
appl = ApplyFatherWavlet1D(wavelet=father_wavelet, 
                           J=J, 
                           img_size=(N,), 
                           padding=father_padding,
                           sample_rate=sample_rate,
                           overlap_log_2=1)
sca_transf = appl.convolve(unpadded_convs)

# it's far more efficient to build the model once and reuse it:
model = Model(inputs=inp, outputs=sca_transf)
# Out:
# WARNING:tensorflow:From /home/blasscock/.edm/envs/PipAll/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/blasscock/.edm/envs/PipAll/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/blasscock/.edm/envs/PipAll/lib/python3.6/site-packages/tensorflow_core/python/ops/variables.py:2825: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# /home/blasscock/sandia-blusky/blusky/wavelets/wavelet_factories_1d.py:46: RuntimeWarning: invalid value encountered in double_scalars
#   step = np.pi * 2**(-J/Q) * (1-1/4*sigma0/_sigma_phi*2**(1./Q))/P

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 4096, 1)      0
# __________________________________________________________________________________________________
# reflection_padding1d_1 (Reflect (None, 5120, 1)      0           input_1[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_2 (Reflect (None, 5127, 1)      0           reflection_padding1d_1[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_3 (Reflect (None, 5135, 1)      0           reflection_padding1d_1[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_4 (Reflect (None, 5151, 1)      0           reflection_padding1d_1[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_5 (Reflect (None, 5183, 1)      0           reflection_padding1d_1[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_6 (Reflect (None, 5247, 1)      0           reflection_padding1d_1[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_7 (Reflect (None, 5375, 1)      0           reflection_padding1d_1[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_8 (Reflect (None, 5631, 1)      0           reflection_padding1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 5120, 1)      8           reflection_padding1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 5120, 1)      8           reflection_padding1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 2560, 1)      16          reflection_padding1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 2560, 1)      16          reflection_padding1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 1280, 1)      32          reflection_padding1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 1280, 1)      32          reflection_padding1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 640, 1)       64          reflection_padding1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 640, 1)       64          reflection_padding1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 320, 1)       128         reflection_padding1d_6[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 320, 1)       128         reflection_padding1d_6[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 160, 1)       256         reflection_padding1d_7[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 160, 1)       256         reflection_padding1d_7[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 80, 1)        512         reflection_padding1d_8[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 80, 1)        512         reflection_padding1d_8[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 5120, 1)      0           conv1d_1[0][0]
#                                                                  conv1d_2[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 2560, 1)      0           conv1d_3[0][0]
#                                                                  conv1d_4[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 1280, 1)      0           conv1d_5[0][0]
#                                                                  conv1d_6[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 640, 1)       0           conv1d_7[0][0]
#                                                                  conv1d_8[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 320, 1)       0           conv1d_9[0][0]
#                                                                  conv1d_10[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 160, 1)       0           conv1d_11[0][0]
#                                                                  conv1d_12[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 80, 1)        0           conv1d_13[0][0]
#                                                                  conv1d_14[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 5120, 1)      0           lambda_1[0][0]
#                                                                  lambda_1[1][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 2560, 1)      0           lambda_2[0][0]
#                                                                  lambda_2[1][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 1280, 1)      0           lambda_3[0][0]
#                                                                  lambda_3[1][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 640, 1)       0           lambda_4[0][0]
#                                                                  lambda_4[1][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 320, 1)       0           lambda_5[0][0]
#                                                                  lambda_5[1][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 160, 1)       0           lambda_6[0][0]
#                                                                  lambda_6[1][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 80, 1)        0           lambda_7[0][0]
#                                                                  lambda_7[1][0]
# __________________________________________________________________________________________________
# xpsi1 (Lambda)                  (None, 5120, 1)      0           add_1[0][0]
# __________________________________________________________________________________________________
# xpsi2 (Lambda)                  (None, 2560, 1)      0           add_2[0][0]
# __________________________________________________________________________________________________
# xpsi3 (Lambda)                  (None, 1280, 1)      0           add_3[0][0]
# __________________________________________________________________________________________________
# xpsi4 (Lambda)                  (None, 640, 1)       0           add_4[0][0]
# __________________________________________________________________________________________________
# xpsi5 (Lambda)                  (None, 320, 1)       0           add_5[0][0]
# __________________________________________________________________________________________________
# xpsi6 (Lambda)                  (None, 160, 1)       0           add_6[0][0]
# __________________________________________________________________________________________________
# xpsi7 (Lambda)                  (None, 80, 1)        0           add_7[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_9 (Reflect (None, 6143, 1)      0           reflection_padding1d_1[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_10 (Reflec (None, 5135, 1)      0           xpsi1[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_11 (Reflec (None, 5151, 1)      0           xpsi1[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_12 (Reflec (None, 5183, 1)      0           xpsi1[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_13 (Reflec (None, 5247, 1)      0           xpsi1[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_14 (Reflec (None, 5375, 1)      0           xpsi1[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_15 (Reflec (None, 5631, 1)      0           xpsi1[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_16 (Reflec (None, 6143, 1)      0           xpsi1[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_17 (Reflec (None, 2575, 1)      0           xpsi2[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_18 (Reflec (None, 2591, 1)      0           xpsi2[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_19 (Reflec (None, 2623, 1)      0           xpsi2[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_20 (Reflec (None, 2687, 1)      0           xpsi2[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_21 (Reflec (None, 2815, 1)      0           xpsi2[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_22 (Reflec (None, 3071, 1)      0           xpsi2[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_23 (Reflec (None, 1295, 1)      0           xpsi3[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_24 (Reflec (None, 1311, 1)      0           xpsi3[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_25 (Reflec (None, 1343, 1)      0           xpsi3[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_26 (Reflec (None, 1407, 1)      0           xpsi3[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_27 (Reflec (None, 1535, 1)      0           xpsi3[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_28 (Reflec (None, 655, 1)       0           xpsi4[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_29 (Reflec (None, 671, 1)       0           xpsi4[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_30 (Reflec (None, 703, 1)       0           xpsi4[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_31 (Reflec (None, 767, 1)       0           xpsi4[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_32 (Reflec (None, 335, 1)       0           xpsi5[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_33 (Reflec (None, 351, 1)       0           xpsi5[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_34 (Reflec (None, 383, 1)       0           xpsi5[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_35 (Reflec (None, 175, 1)       0           xpsi6[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_36 (Reflec (None, 191, 1)       0           xpsi6[0][0]
# __________________________________________________________________________________________________
# reflection_padding1d_37 (Reflec (None, 95, 1)        0           xpsi7[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 40, 1)        1024        reflection_padding1d_9[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 40, 1)        1024        reflection_padding1d_9[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 2560, 1)      16          reflection_padding1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 2560, 1)      16          reflection_padding1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 1280, 1)      32          reflection_padding1d_11[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 1280, 1)      32          reflection_padding1d_11[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 640, 1)       64          reflection_padding1d_12[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 640, 1)       64          reflection_padding1d_12[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 320, 1)       128         reflection_padding1d_13[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 320, 1)       128         reflection_padding1d_13[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 160, 1)       256         reflection_padding1d_14[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 160, 1)       256         reflection_padding1d_14[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 80, 1)        512         reflection_padding1d_15[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 80, 1)        512         reflection_padding1d_15[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 40, 1)        1024        reflection_padding1d_16[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 40, 1)        1024        reflection_padding1d_16[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 1280, 1)      16          reflection_padding1d_17[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 1280, 1)      16          reflection_padding1d_17[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 640, 1)       32          reflection_padding1d_18[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 640, 1)       32          reflection_padding1d_18[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 320, 1)       64          reflection_padding1d_19[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 320, 1)       64          reflection_padding1d_19[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 160, 1)       128         reflection_padding1d_20[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 160, 1)       128         reflection_padding1d_20[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 80, 1)        256         reflection_padding1d_21[0][0]
# __________________________________________________________________________________________________
# conv1d_40 (Conv1D)              (None, 80, 1)        256         reflection_padding1d_21[0][0]
# __________________________________________________________________________________________________
# conv1d_41 (Conv1D)              (None, 40, 1)        512         reflection_padding1d_22[0][0]
# __________________________________________________________________________________________________
# conv1d_42 (Conv1D)              (None, 40, 1)        512         reflection_padding1d_22[0][0]
# __________________________________________________________________________________________________
# conv1d_43 (Conv1D)              (None, 640, 1)       16          reflection_padding1d_23[0][0]
# __________________________________________________________________________________________________
# conv1d_44 (Conv1D)              (None, 640, 1)       16          reflection_padding1d_23[0][0]
# __________________________________________________________________________________________________
# conv1d_45 (Conv1D)              (None, 320, 1)       32          reflection_padding1d_24[0][0]
# __________________________________________________________________________________________________
# conv1d_46 (Conv1D)              (None, 320, 1)       32          reflection_padding1d_24[0][0]
# __________________________________________________________________________________________________
# conv1d_47 (Conv1D)              (None, 160, 1)       64          reflection_padding1d_25[0][0]
# __________________________________________________________________________________________________
# conv1d_48 (Conv1D)              (None, 160, 1)       64          reflection_padding1d_25[0][0]
# __________________________________________________________________________________________________
# conv1d_49 (Conv1D)              (None, 80, 1)        128         reflection_padding1d_26[0][0]
# __________________________________________________________________________________________________
# conv1d_50 (Conv1D)              (None, 80, 1)        128         reflection_padding1d_26[0][0]
# __________________________________________________________________________________________________
# conv1d_51 (Conv1D)              (None, 40, 1)        256         reflection_padding1d_27[0][0]
# __________________________________________________________________________________________________
# conv1d_52 (Conv1D)              (None, 40, 1)        256         reflection_padding1d_27[0][0]
# __________________________________________________________________________________________________
# conv1d_53 (Conv1D)              (None, 320, 1)       16          reflection_padding1d_28[0][0]
# __________________________________________________________________________________________________
# conv1d_54 (Conv1D)              (None, 320, 1)       16          reflection_padding1d_28[0][0]
# __________________________________________________________________________________________________
# conv1d_55 (Conv1D)              (None, 160, 1)       32          reflection_padding1d_29[0][0]
# __________________________________________________________________________________________________
# conv1d_56 (Conv1D)              (None, 160, 1)       32          reflection_padding1d_29[0][0]
# __________________________________________________________________________________________________
# conv1d_57 (Conv1D)              (None, 80, 1)        64          reflection_padding1d_30[0][0]
# __________________________________________________________________________________________________
# conv1d_58 (Conv1D)              (None, 80, 1)        64          reflection_padding1d_30[0][0]
# __________________________________________________________________________________________________
# conv1d_59 (Conv1D)              (None, 40, 1)        128         reflection_padding1d_31[0][0]
# __________________________________________________________________________________________________
# conv1d_60 (Conv1D)              (None, 40, 1)        128         reflection_padding1d_31[0][0]
# __________________________________________________________________________________________________
# conv1d_61 (Conv1D)              (None, 160, 1)       16          reflection_padding1d_32[0][0]
# __________________________________________________________________________________________________
# conv1d_62 (Conv1D)              (None, 160, 1)       16          reflection_padding1d_32[0][0]
# __________________________________________________________________________________________________
# conv1d_63 (Conv1D)              (None, 80, 1)        32          reflection_padding1d_33[0][0]
# __________________________________________________________________________________________________
# conv1d_64 (Conv1D)              (None, 80, 1)        32          reflection_padding1d_33[0][0]
# __________________________________________________________________________________________________
# conv1d_65 (Conv1D)              (None, 40, 1)        64          reflection_padding1d_34[0][0]
# __________________________________________________________________________________________________
# conv1d_66 (Conv1D)              (None, 40, 1)        64          reflection_padding1d_34[0][0]
# __________________________________________________________________________________________________
# conv1d_67 (Conv1D)              (None, 80, 1)        16          reflection_padding1d_35[0][0]
# __________________________________________________________________________________________________
# conv1d_68 (Conv1D)              (None, 80, 1)        16          reflection_padding1d_35[0][0]
# __________________________________________________________________________________________________
# conv1d_69 (Conv1D)              (None, 40, 1)        32          reflection_padding1d_36[0][0]
# __________________________________________________________________________________________________
# conv1d_70 (Conv1D)              (None, 40, 1)        32          reflection_padding1d_36[0][0]
# __________________________________________________________________________________________________
# conv1d_71 (Conv1D)              (None, 40, 1)        16          reflection_padding1d_37[0][0]
# __________________________________________________________________________________________________
# conv1d_72 (Conv1D)              (None, 40, 1)        16          reflection_padding1d_37[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 40, 1)        0           conv1d_15[0][0]
#                                                                  conv1d_16[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 2560, 1)      0           conv1d_17[0][0]
#                                                                  conv1d_18[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 1280, 1)      0           conv1d_19[0][0]
#                                                                  conv1d_20[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 640, 1)       0           conv1d_21[0][0]
#                                                                  conv1d_22[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 320, 1)       0           conv1d_23[0][0]
#                                                                  conv1d_24[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 160, 1)       0           conv1d_25[0][0]
#                                                                  conv1d_26[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 80, 1)        0           conv1d_27[0][0]
#                                                                  conv1d_28[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 40, 1)        0           conv1d_29[0][0]
#                                                                  conv1d_30[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 1280, 1)      0           conv1d_31[0][0]
#                                                                  conv1d_32[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 640, 1)       0           conv1d_33[0][0]
#                                                                  conv1d_34[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 320, 1)       0           conv1d_35[0][0]
#                                                                  conv1d_36[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 160, 1)       0           conv1d_37[0][0]
#                                                                  conv1d_38[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 80, 1)        0           conv1d_39[0][0]
#                                                                  conv1d_40[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 40, 1)        0           conv1d_41[0][0]
#                                                                  conv1d_42[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 640, 1)       0           conv1d_43[0][0]
#                                                                  conv1d_44[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 320, 1)       0           conv1d_45[0][0]
#                                                                  conv1d_46[0][0]
# __________________________________________________________________________________________________
# lambda_24 (Lambda)              (None, 160, 1)       0           conv1d_47[0][0]
#                                                                  conv1d_48[0][0]
# __________________________________________________________________________________________________
# lambda_25 (Lambda)              (None, 80, 1)        0           conv1d_49[0][0]
#                                                                  conv1d_50[0][0]
# __________________________________________________________________________________________________
# lambda_26 (Lambda)              (None, 40, 1)        0           conv1d_51[0][0]
#                                                                  conv1d_52[0][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, 320, 1)       0           conv1d_53[0][0]
#                                                                  conv1d_54[0][0]
# __________________________________________________________________________________________________
# lambda_28 (Lambda)              (None, 160, 1)       0           conv1d_55[0][0]
#                                                                  conv1d_56[0][0]
# __________________________________________________________________________________________________
# lambda_29 (Lambda)              (None, 80, 1)        0           conv1d_57[0][0]
#                                                                  conv1d_58[0][0]
# __________________________________________________________________________________________________
# lambda_30 (Lambda)              (None, 40, 1)        0           conv1d_59[0][0]
#                                                                  conv1d_60[0][0]
# __________________________________________________________________________________________________
# lambda_31 (Lambda)              (None, 160, 1)       0           conv1d_61[0][0]
#                                                                  conv1d_62[0][0]
# __________________________________________________________________________________________________
# lambda_32 (Lambda)              (None, 80, 1)        0           conv1d_63[0][0]
#                                                                  conv1d_64[0][0]
# __________________________________________________________________________________________________
# lambda_33 (Lambda)              (None, 40, 1)        0           conv1d_65[0][0]
#                                                                  conv1d_66[0][0]
# __________________________________________________________________________________________________
# lambda_34 (Lambda)              (None, 80, 1)        0           conv1d_67[0][0]
#                                                                  conv1d_68[0][0]
# __________________________________________________________________________________________________
# lambda_35 (Lambda)              (None, 40, 1)        0           conv1d_69[0][0]
#                                                                  conv1d_70[0][0]
# __________________________________________________________________________________________________
# lambda_36 (Lambda)              (None, 40, 1)        0           conv1d_71[0][0]
#                                                                  conv1d_72[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 40, 1)        0           lambda_8[0][0]
#                                                                  lambda_8[1][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 2560, 1)      0           lambda_9[0][0]
#                                                                  lambda_9[1][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 1280, 1)      0           lambda_10[0][0]
#                                                                  lambda_10[1][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 640, 1)       0           lambda_11[0][0]
#                                                                  lambda_11[1][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 320, 1)       0           lambda_12[0][0]
#                                                                  lambda_12[1][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 160, 1)       0           lambda_13[0][0]
#                                                                  lambda_13[1][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 80, 1)        0           lambda_14[0][0]
#                                                                  lambda_14[1][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 40, 1)        0           lambda_15[0][0]
#                                                                  lambda_15[1][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 1280, 1)      0           lambda_16[0][0]
#                                                                  lambda_16[1][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 640, 1)       0           lambda_17[0][0]
#                                                                  lambda_17[1][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 320, 1)       0           lambda_18[0][0]
#                                                                  lambda_18[1][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 160, 1)       0           lambda_19[0][0]
#                                                                  lambda_19[1][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 80, 1)        0           lambda_20[0][0]
#                                                                  lambda_20[1][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 40, 1)        0           lambda_21[0][0]
#                                                                  lambda_21[1][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 640, 1)       0           lambda_22[0][0]
#                                                                  lambda_22[1][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 320, 1)       0           lambda_23[0][0]
#                                                                  lambda_23[1][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 160, 1)       0           lambda_24[0][0]
#                                                                  lambda_24[1][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 80, 1)        0           lambda_25[0][0]
#                                                                  lambda_25[1][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 40, 1)        0           lambda_26[0][0]
#                                                                  lambda_26[1][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 320, 1)       0           lambda_27[0][0]
#                                                                  lambda_27[1][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 160, 1)       0           lambda_28[0][0]
#                                                                  lambda_28[1][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 80, 1)        0           lambda_29[0][0]
#                                                                  lambda_29[1][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 40, 1)        0           lambda_30[0][0]
#                                                                  lambda_30[1][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 160, 1)       0           lambda_31[0][0]
#                                                                  lambda_31[1][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 80, 1)        0           lambda_32[0][0]
#                                                                  lambda_32[1][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 40, 1)        0           lambda_33[0][0]
#                                                                  lambda_33[1][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, 80, 1)        0           lambda_34[0][0]
#                                                                  lambda_34[1][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, 40, 1)        0           lambda_35[0][0]
#                                                                  lambda_35[1][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, 40, 1)        0           lambda_36[0][0]
#                                                                  lambda_36[1][0]
# __________________________________________________________________________________________________
# xpsi8 (Lambda)                  (None, 40, 1)        0           add_8[0][0]
# __________________________________________________________________________________________________
# xpsi1psi2 (Lambda)              (None, 2560, 1)      0           add_9[0][0]
# __________________________________________________________________________________________________
# xpsi1psi3 (Lambda)              (None, 1280, 1)      0           add_10[0][0]
# __________________________________________________________________________________________________
# xpsi1psi4 (Lambda)              (None, 640, 1)       0           add_11[0][0]
# __________________________________________________________________________________________________
# xpsi1psi5 (Lambda)              (None, 320, 1)       0           add_12[0][0]
# __________________________________________________________________________________________________
# xpsi1psi6 (Lambda)              (None, 160, 1)       0           add_13[0][0]
# __________________________________________________________________________________________________
# xpsi1psi7 (Lambda)              (None, 80, 1)        0           add_14[0][0]
# __________________________________________________________________________________________________
# xpsi1psi8 (Lambda)              (None, 40, 1)        0           add_15[0][0]
# __________________________________________________________________________________________________
# xpsi2psi3 (Lambda)              (None, 1280, 1)      0           add_16[0][0]
# __________________________________________________________________________________________________
# xpsi2psi4 (Lambda)              (None, 640, 1)       0           add_17[0][0]
# __________________________________________________________________________________________________
# xpsi2psi5 (Lambda)              (None, 320, 1)       0           add_18[0][0]
# __________________________________________________________________________________________________
# xpsi2psi6 (Lambda)              (None, 160, 1)       0           add_19[0][0]
# __________________________________________________________________________________________________
# xpsi2psi7 (Lambda)              (None, 80, 1)        0           add_20[0][0]
# __________________________________________________________________________________________________
# xpsi2psi8 (Lambda)              (None, 40, 1)        0           add_21[0][0]
# __________________________________________________________________________________________________
# xpsi3psi4 (Lambda)              (None, 640, 1)       0           add_22[0][0]
# __________________________________________________________________________________________________
# xpsi3psi5 (Lambda)              (None, 320, 1)       0           add_23[0][0]
# ...
# __________________________________________________________________________________________________
# xpsi4psi8 (Lambda)              (None, 40, 1)        0           add_30[0][0]
# __________________________________________________________________________________________________
# xpsi5psi6 (Lambda)              (None, 160, 1)       0           add_31[0][0]
# __________________________________________________________________________________________________
# xpsi5psi7 (Lambda)              (None, 80, 1)        0           add_32[0][0]
# __________________________________________________________________________________________________
# xpsi5psi8 (Lambda)              (None, 40, 1)        0           add_33[0][0]
# __________________________________________________________________________________________________
# xpsi6psi7 (Lambda)              (None, 80, 1)        0           add_34[0][0]
# __________________________________________________________________________________________________
# xpsi6psi8 (Lambda)              (None, 40, 1)        0           add_35[0][0]
# __________________________________________________________________________________________________
# xpsi7psi8 (Lambda)              (None, 40, 1)        0           add_36[0][0]
# __________________________________________________________________________________________________
# xpsi1unpadded (Lambda)          (None, 4096, 1)      0           xpsi1[0][0]
# __________________________________________________________________________________________________
# xpsi2unpadded (Lambda)          (None, 2048, 1)      0           xpsi2[0][0]
# __________________________________________________________________________________________________
# xpsi3unpadded (Lambda)          (None, 1024, 1)      0           xpsi3[0][0]
# __________________________________________________________________________________________________
# xpsi4unpadded (Lambda)          (None, 512, 1)       0           xpsi4[0][0]
# __________________________________________________________________________________________________
# xpsi5unpadded (Lambda)          (None, 256, 1)       0           xpsi5[0][0]
# __________________________________________________________________________________________________
# xpsi6unpadded (Lambda)          (None, 128, 1)       0           xpsi6[0][0]
# __________________________________________________________________________________________________
# xpsi7unpadded (Lambda)          (None, 64, 1)        0           xpsi7[0][0]
# __________________________________________________________________________________________________
# xpsi8unpadded (Lambda)          (None, 32, 1)        0           xpsi8[0][0]
# __________________________________________________________________________________________________
# xpsi1psi2unpadded (Lambda)      (None, 2048, 1)      0           xpsi1psi2[0][0]
# __________________________________________________________________________________________________
# xpsi1psi3unpadded (Lambda)      (None, 1024, 1)      0           xpsi1psi3[0][0]
# __________________________________________________________________________________________________
# xpsi1psi4unpadded (Lambda)      (None, 512, 1)       0           xpsi1psi4[0][0]
# __________________________________________________________________________________________________
# xpsi1psi5unpadded (Lambda)      (None, 256, 1)       0           xpsi1psi5[0][0]
# __________________________________________________________________________________________________
# xpsi1psi6unpadded (Lambda)      (None, 128, 1)       0           xpsi1psi6[0][0]
# __________________________________________________________________________________________________
# xpsi1psi7unpadded (Lambda)      (None, 64, 1)        0           xpsi1psi7[0][0]
# __________________________________________________________________________________________________
# xpsi1psi8unpadded (Lambda)      (None, 32, 1)        0           xpsi1psi8[0][0]
# __________________________________________________________________________________________________
# xpsi2psi3unpadded (Lambda)      (None, 1024, 1)      0           xpsi2psi3[0][0]
# __________________________________________________________________________________________________
# xpsi2psi4unpadded (Lambda)      (None, 512, 1)       0           xpsi2psi4[0][0]
# __________________________________________________________________________________________________
# xpsi2psi5unpadded (Lambda)      (None, 256, 1)       0           xpsi2psi5[0][0]
# __________________________________________________________________________________________________
# xpsi2psi6unpadded (Lambda)      (None, 128, 1)       0           xpsi2psi6[0][0]
# __________________________________________________________________________________________________
# xpsi2psi7unpadded (Lambda)      (None, 64, 1)        0           xpsi2psi7[0][0]
# __________________________________________________________________________________________________
# xpsi2psi8unpadded (Lambda)      (None, 32, 1)        0           xpsi2psi8[0][0]
# __________________________________________________________________________________________________
# xpsi3psi4unpadded (Lambda)      (None, 512, 1)       0           xpsi3psi4[0][0]
# __________________________________________________________________________________________________
# xpsi3psi5unpadded (Lambda)      (None, 256, 1)       0           xpsi3psi5[0][0]
# __________________________________________________________________________________________________
# xpsi3psi6unpadded (Lambda)      (None, 128, 1)       0           xpsi3psi6[0][0]
# __________________________________________________________________________________________________
# xpsi3psi7unpadded (Lambda)      (None, 64, 1)        0           xpsi3psi7[0][0]
# __________________________________________________________________________________________________
# xpsi3psi8unpadded (Lambda)      (None, 32, 1)        0           xpsi3psi8[0][0]
# __________________________________________________________________________________________________
# xpsi4psi5unpadded (Lambda)      (None, 256, 1)       0           xpsi4psi5[0][0]
# __________________________________________________________________________________________________
# xpsi4psi6unpadded (Lambda)      (None, 128, 1)       0           xpsi4psi6[0][0]
# __________________________________________________________________________________________________
# xpsi4psi7unpadded (Lambda)      (None, 64, 1)        0           xpsi4psi7[0][0]
# __________________________________________________________________________________________________
# xpsi4psi8unpadded (Lambda)      (None, 32, 1)        0           xpsi4psi8[0][0]
# __________________________________________________________________________________________________
# xpsi5psi6unpadded (Lambda)      (None, 128, 1)       0           xpsi5psi6[0][0]
# __________________________________________________________________________________________________
# xpsi5psi7unpadded (Lambda)      (None, 64, 1)        0           xpsi5psi7[0][0]
# __________________________________________________________________________________________________
# xpsi5psi8unpadded (Lambda)      (None, 32, 1)        0           xpsi5psi8[0][0]
# __________________________________________________________________________________________________
# xpsi6psi7unpadded (Lambda)      (None, 64, 1)        0           xpsi6psi7[0][0]
# __________________________________________________________________________________________________
# xpsi6psi8unpadded (Lambda)      (None, 32, 1)        0           xpsi6psi8[0][0]
# __________________________________________________________________________________________________
# xpsi7psi8unpadded (Lambda)      (None, 32, 1)        0           xpsi7psi8[0][0]
# __________________________________________________________________________________________________
# xpsi1unpaddedphi (Conv1D)       (None, 7, 1)         1024        xpsi1unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi2unpaddedphi (Conv1D)       (None, 7, 1)         512         xpsi2unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi3unpaddedphi (Conv1D)       (None, 7, 1)         256         xpsi3unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi4unpaddedphi (Conv1D)       (None, 7, 1)         128         xpsi4unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi5unpaddedphi (Conv1D)       (None, 7, 1)         64          xpsi5unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi6unpaddedphi (Conv1D)       (None, 7, 1)         32          xpsi6unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi7unpaddedphi (Conv1D)       (None, 7, 1)         16          xpsi7unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi8unpaddedphi (Conv1D)       (None, 7, 1)         8           xpsi8unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi1psi2unpaddedphi (Conv1D)   (None, 7, 1)         512         xpsi1psi2unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi1psi3unpaddedphi (Conv1D)   (None, 7, 1)         256         xpsi1psi3unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi1psi4unpaddedphi (Conv1D)   (None, 7, 1)         128         xpsi1psi4unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi1psi5unpaddedphi (Conv1D)   (None, 7, 1)         64          xpsi1psi5unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi1psi6unpaddedphi (Conv1D)   (None, 7, 1)         32          xpsi1psi6unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi1psi7unpaddedphi (Conv1D)   (None, 7, 1)         16          xpsi1psi7unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi1psi8unpaddedphi (Conv1D)   (None, 7, 1)         8           xpsi1psi8unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi2psi3unpaddedphi (Conv1D)   (None, 7, 1)         256         xpsi2psi3unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi2psi4unpaddedphi (Conv1D)   (None, 7, 1)         128         xpsi2psi4unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi2psi5unpaddedphi (Conv1D)   (None, 7, 1)         64          xpsi2psi5unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi2psi6unpaddedphi (Conv1D)   (None, 7, 1)         32          xpsi2psi6unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi2psi7unpaddedphi (Conv1D)   (None, 7, 1)         16          xpsi2psi7unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi2psi8unpaddedphi (Conv1D)   (None, 7, 1)         8           xpsi2psi8unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi3psi4unpaddedphi (Conv1D)   (None, 7, 1)         128         xpsi3psi4unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi3psi5unpaddedphi (Conv1D)   (None, 7, 1)         64          xpsi3psi5unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi3psi6unpaddedphi (Conv1D)   (None, 7, 1)         32          xpsi3psi6unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi3psi7unpaddedphi (Conv1D)   (None, 7, 1)         16          xpsi3psi7unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi3psi8unpaddedphi (Conv1D)   (None, 7, 1)         8           xpsi3psi8unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi4psi5unpaddedphi (Conv1D)   (None, 7, 1)         64          xpsi4psi5unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi4psi6unpaddedphi (Conv1D)   (None, 7, 1)         32          xpsi4psi6unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi4psi7unpaddedphi (Conv1D)   (None, 7, 1)         16          xpsi4psi7unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi4psi8unpaddedphi (Conv1D)   (None, 7, 1)         8           xpsi4psi8unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi5psi6unpaddedphi (Conv1D)   (None, 7, 1)         32          xpsi5psi6unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi5psi7unpaddedphi (Conv1D)   (None, 7, 1)         16          xpsi5psi7unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi5psi8unpaddedphi (Conv1D)   (None, 7, 1)         8           xpsi5psi8unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi6psi7unpaddedphi (Conv1D)   (None, 7, 1)         16          xpsi6psi7unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi6psi8unpaddedphi (Conv1D)   (None, 7, 1)         8           xpsi6psi8unpadded[0][0]
# __________________________________________________________________________________________________
# xpsi7psi8unpaddedphi (Conv1D)   (None, 7, 1)         8           xpsi7psi8unpadded[0][0]
# ==================================================================================================
# Total params: 16,000
# Trainable params: 0
# Non-trainable params: 16,000
# __________________________________________________________________________________________________

# %%
ddelta = np.zeros(N)
ddelta[N//2] = 1
delta = model.predict(np.expand_dims(np.expand_dims(ddelta,axis=0), axis=-1))
# Out:
# WARNING:tensorflow:From /home/blasscock/.edm/envs/PipAll/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/blasscock/.edm/envs/PipAll/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /home/blasscock/.edm/envs/PipAll/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/blasscock/.edm/envs/PipAll/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /home/blasscock/.edm/envs/PipAll/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /home/blasscock/.edm/envs/PipAll/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.

# %%
_J = J
_N = range(len(delta))[::-1]

scale_order = []
counter = 0
for i,__order in enumerate(range(_J)[::-1]):
    scale_order.append(__order)
    for _i in range(i):
       scale_order.append(_N[counter])
       counter += 1

# %%
def pseudo_dirac_norm(f, delta, scale_order):
    """ Not 100%, but normalizes each coefficient by the corresponding dirac
        delta coefficient, and resamples the vector on a interval proportional 
        to the relative power in the delta's "power" spectrum
    """
    #_f = np.squeeze([np.linalg.norm(f[i][0,:,0])/np.linalg.norm(delta[i][0,:,0]) for i in scale_order])
    #_dirac = np.squeeze([np.linalg.norm(delta[i][0,:,0])**2 for i in scale_order])
    #_f = np.squeeze([f[i][0,:,0]/delta[i][0,:,0] for i in scale_order])
    
    _f = np.hstack([f[i][0,:,0]/delta[i][0,:,0] for i in scale_order])
    
    #_dirac = np.squeeze([delta[i][0,:,0]**2 for i in scale_order])
    _dirac = np.hstack(np.array([delta[i][0,:,0]**2 for i in scale_order]))
    
    C = np.sum(_dirac)

    #_N = len(_dirac)*10
    _N = len(_dirac)
    step = np.int_(_N*_dirac/C)

    k0 = 1
    result = np.zeros(np.sum(step)+1)
    for i,k in enumerate(step):
        result[k0:k0+k] = _f[i]
        k0 += k
        
    return result

# %%
np.sum(f1)
# Out:
# 1.0

# %%
f1_res = model.predict(np.expand_dims(np.expand_dims(f1,axis=0), axis=-1))
f2_res = model.predict(np.expand_dims(np.expand_dims(f2,axis=0), axis=-1))
f3_res = model.predict(np.expand_dims(np.expand_dims(f3,axis=0), axis=-1))
f4_res = model.predict(np.expand_dims(np.expand_dims(f4,axis=0), axis=-1))

scat1 = pseudo_dirac_norm(f1_res, delta, scale_order)
scat1[0] = np.sum(f1)
scat2 = pseudo_dirac_norm(f2_res, delta, scale_order)
scat2[0] = np.sum(f2)
scat3 = pseudo_dirac_norm(f3_res, delta, scale_order)
scat3[0] = np.sum(f3)
scat4 = pseudo_dirac_norm(f4_res, delta, scale_order)
scat4[0] = np.sum(f4)
# Out:
# /home/blasscock/.edm/envs/PipAll/lib/python3.6/site-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in true_divide
#   # Remove the CWD from sys.path while we load stuff.
# /home/blasscock/.edm/envs/PipAll/lib/python3.6/site-packages/ipykernel_launcher.py:10: RuntimeWarning: divide by zero encountered in true_divide
#   # Remove the CWD from sys.path while we load stuff.

# %%
(
 np.linalg.norm(scat2 - scat3)/(np.linalg.norm(scat2)*np.linalg.norm(scat3)), 
 np.linalg.norm(f2 - f3)/(np.linalg.norm(f2)*np.linalg.norm(f3)), 
 np.linalg.norm(fft(f2) - fft(f3))/(np.linalg.norm(fft(f2))*np.linalg.norm(fft(f3)))
)
# Out:
# (0.35138576762124074, 11.745509187983357, 0.18352358106223998)

# %%
np.linalg.norm(fft(f2) - fft(f3))
# Out:
# 11.466920391931737

# %%
np.linalg.norm(np.fft(f2) - np.fft(f3))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-aded2ec302a9> in <module>
# ----> 1 np.linalg.norm(np.fft(f2) - np.fft(f3))
#
# TypeError: 'module' object is not callable

# %%
plt.plot(scat1)

# %%
start_plot = np.int(N/2 - 4*R)
end_plot = np.int(N/2 + 4*R)

#domain for f1
num = f1[start_plot:end_plot].shape[0]
w = np.arange(1,num+1)
w = (w-1) * 8/num -4

# domain for f2 to f4
num = 16*R+1
w2 = np.arange(1,num)
w2 = (w2-1) * 8/num -4

# domain for fourier series
P = np.int(N/2)
z = np.arange(0,P)
z = 10*z*2*np.pi / P

# Why? get it!
#y = np.linspace(0,40,len(scat1))
y = 10*np.arange(len(scat1))*2*np.pi / len(scat1)

fig, ax = plt.subplots(4,3, figsize=(15,10))

ax[0,0].plot(w,f1[start_plot:end_plot])
ax[0,0].set_xlim((-4,4))
ax[0,0].set_ylim((0,0.04))
ax[0,1].plot(z,A1[0:np.int(N/2)])
ax[0,1].set_xlim((0,40))
ax[0,1].set_ylim((0,1))
ax[0,1].set_yticks([0, 0.5, 1])
ax[0,2].plot(y,scat1)
ax[0,2].set_ylim((0,1))
ax[0,2].set_xlim((0,65))

ax[1,0].plot(w2,f2[np.int(N/2 - 8*R):np.int(N/2 + 8*R)])
ax[1,0].set_xlim((-4,4))
ax[1,0].set_ylim((-0.02,.02))
ax[1,1].plot(z,A2[0:np.int(N/2)])
ax[1,1].set_xlim((0,40))
ax[1,1].set_ylim((0,1))
ax[1,1].set_yticks([0, 0.5, 1])
ax[1,2].plot(y,scat2)
ax[1,2].set_ylim((0,1))
ax[1,2].set_xlim((0,65))

ax[2,0].plot(w2,f3[np.int(N/2 - 8*R):np.int(N/2 + 8*R)])
ax[2,0].set_xlim((-4,4))
ax[2,0].set_ylim((-0.02,0.02))
ax[2,1].plot(z,A3[0:np.int(N/2)])
ax[2,1].set_xlim((0,40))
ax[2,1].set_ylim((0,1))
ax[2,1].set_yticks([0, 0.5, 1])
ax[2,2].plot(y,scat3)
ax[2,2].set_ylim((0,1))
ax[2,2].set_xlim((0,65))

ax[3,0].plot(w2,f4[np.int(N/2 - 8*R):np.int(N/2 + 8*R)])
ax[3,0].set_xlim((-4,4))
ax[3,0].set_ylim((-0.02,0.02))
ax[3,1].plot(z,A4[0:np.int(N/2)])
ax[3,1].set_xlim((0,40))
ax[3,1].set_ylim((0,1))
ax[3,1].set_yticks([0, 0.5, 1])
ax[3,2].plot(y,scat4)
ax[3,2].set_ylim((0,1))
ax[3,2].set_xlim((0,65))

# %% [markdown]
# ## This is Figure 3 in the GIS paper:
#
# <img src="GIS_figure3.png">
#
# This is the MATLAB code to generate Figure 3 (above) in the GIS paper.

# %% [markdown]
# ```python
# % Reproduction of the Figure 3.2 of in the paper:
# % “Group Invariant Scattering”, S. Mallat,
# % Comm. in Pure and Applied Mathematics, Dec. 2012, Wiley
# %
# % Fourier transforms and scattering transforms of 4 different signals.
#
# N = 8*1024; %signal size, power of two
# Jmax = log2(N); %Maximum number of scales
# %Choice of the wavelet
# fparam.filter_type = {‘spline_1d’};
# fparam.spline_order=3;
# % Scale 2^J selected to display the scattering representation
# fparam.J = Jmax-1;
# fparam.Q = 1;
# options.M = fparam.J;
# Wop = wavelet_factory_1d(N, fparam, options);
# % Examples of signals
# %Indicator function of an interval
# f1 = zeros(1,N);
# R = 20;
#   f1(N/2-R:N/2+R) = 1;
# f1 = f1 ./sum(abs(f1));
# f1=f1';
# % Scattering transform
# % tic
#  Scat1 = diracNormScatt(f1,Wop);
# % toc
# P = length(Scat1);
# y = zeros(1,P);
# y(1:P) = (1:P);
# y = 10 * y* 2 * pi/(P);
# P = 8*R+1;
# w = zeros(1,R);
# w(1:P) = (1:P);
# w = (w-1)*8/(P)-4;
# figure(1);
# hold off;
# subplot(4,3,1), plot(w,f1(N/2-4*R:N/2+4*R));
# %subplot(4,3,3), plotnormScatt(y,Scat1, Sdirac1, order1); %Scattered representation at the scale 2^J
# subplot(4,3,3), plot(y,Scat1); %Scattered representation at the scale 2^J
# % Modulus of the Fourier transform
# A1 = abs(fft(f1));
# P = N/2;
# z = zeros(1,P);
# z(1:P) = (1:P);
# z =10 *  z* 2 * pi/(P);
# subplot(4,3,2), plot(z,A1(1:N/2));
# %plot(Scat1(:,J-1),‘g’);
# hold off;
# P = 16*R+1;
# w = zeros(1,P);
# w(1:P) = (1:P);
# %w = w* 50(P);
# w = (w-1)*8/(P)-4;
# %First Gabor function
# f1 = zeros(1,N);
# R = 20;
#
#   f1(1:N) = exp(-((1:N)-N/2).^2/(2 * (1024/32).^2)) .* cos(pi * (1:N)*0.90/3);
#
#
# f1 = f1 ./sum(abs(f1));
# f1=f1';
# Scat1 = diracNormScatt(f1,Wop);
# P = length(Scat1);
# y = zeros(1,P);
# y(1:P) = (1:P);
# y = 10 * y* 2 * pi/(P);
# hold off;
# subplot(4,3,4), plot(w,f1(N/2-8*R:N/2+8*R));
# subplot(4,3,6), plot(y,Scat1); %Scattered representation at the scale 2^J
# A1 = abs(fft(f1));
# P = N/2;
# z = zeros(1,P);
# z(1:P) = (1:P);
# z = 10 * z* 2 * pi/(P);
# subplot(4,3,5), plot(z,A1(1:N/2));
# %plot(Scat1(:,J-1),‘g’);
# hold off;
# %Dilated Gabor Function
# f2 = zeros(1,N);
# R = 20;
#   f2(1:N) = exp(-(1.1).^2*((1:N)-N/2).^2/(2 * (1024/32).^2)) .* cos(pi * (1:N)*1.1*0.9/3);
# f2 = f2 ./sum(abs(f2));
# f2=f2';
# subplot(4,3,7), plot(w,f2(N/2-8*R:N/2+8*R));
# Scat2 = diracNormScatt(f2,Wop);
# %Scat2 = NormScatter(f2,wavelet_name,Jmax,‘White’);
# %Scat = Scatter(f2,wavelet_name,Jmax,‘White’);
# %figure(2);
# hold off;
# subplot(4,3,9),plot(y,Scat2); %Scattered representation at the scale 2^J
# A2 = abs(fft(f2));
# P = N/2;
# z(1:P) = (1:P);
# z = 10 * z* 2 * pi/(P);
# subplot(4,3,8), plot(z,A2(1:N/2));
# hold on;
# %plot(Scat2(:,J-1),‘g’);
# hold off;
# %sum of a Gabor function and of a dilated Gabor function
# f4 = zeros(1,N);
# R = 20;
#   f4(1:N) = exp(-((1:N)-N/2).^2/(2 * (1024/16).^2)) .* cos(pi * (1:N)*0.95/3) + exp(-((1:N)-N/2).^2/(2 * (1024/16).^2)) .* cos(pi * (1:N)*1/3*1.05) ;
# f4 = f4 ./sum(abs(f4));
# f4=f4';
# Scat4 = diracNormScatt(f4,Wop);
# P = length(Scat4);
# y = zeros(1,P);
# y(1:P) = (1:P);
# y = 10 * y* 2 * pi/(P);
# hold off;
# subplot(4,3,10), plot(w,f4(N/2-8*R:N/2+8*R));
# subplot(4,3,12), plot(y,Scat4); %Scattered representation at the scale 2^J
# A4 = abs(fft(f4));
# P = N/2;
# z = zeros(1,P);
# z(1:P) = (1:P);
# z = 10 * z* 2 * pi/(P);
# subplot(4,3,11), plot(z,A4(1:N/2));
# %plot(Scat4(:,J-1),‘g’);
# hold off;
# fprintf(‘Left graphs: each row gives an example of function fi(x). \n Middle graphs: modulus of the Fourier transform of each fi \n as a function of the freRuency omega.\n Right graphs: normalized scattering transforms Sfi(R(omega))\n as a function of the freRuency omega.\n’);
# ```
